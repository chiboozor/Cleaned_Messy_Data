# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('messy_data.csv', encoding='Latin-1', sep=';')

# %%
df.head()
# Out:
#   IMBD title ID            Original titlÊ  Release year                Genrë¨  \
# 0     tt0111161  The Shawshank Redemption    1995-02-10                 Drama
# 1     tt0068646             The Godfather    09 21 1972          Crime, Drama
# 2     tt0468569           The Dark Knight   23 -07-2008  Action, Crime, Drama
# 3     tt0071562    The Godfather: Part II    1975-09-25          Crime, Drama
# 4     tt0110912              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Duration Country Content Rating              Director  Unnamed: 8  \
# 0      142     USA              R        Frank Darabont         NaN
# 1      175     USA              R  Francis Ford Coppola         NaN
# 2      152      US          PG-13     Christopher Nolan         NaN
# 3      220     USA              R  Francis Ford Coppola         NaN
# 4              USA              R     Quentin Tarantino         NaN
#
#           Income     Votes  Score
# 0     $ 28815245  2.278.845   9.3
# 1    $ 246120974  1.572.674   9.2
# 2   $ 1005455211  2.241.615    9.
# 3  $ 4o8,035,783  1.098.714  9,.0
# 4    $ 222831817  1.780.147  8,9f

# %% [markdown]
# # Check for duplicate rows and dropping unnecessary columns.

# %%
# Check for duplicate rows in the dataset.

sum(df.duplicated())
# Out:
# 0

# %%
# Dropping the 'Imbd title Id' and 'Unnamed: 8' columns.

df.drop(columns = ['IMBD title ID', 'Unnamed: 8'], axis=1, inplace=True)

# %%
df.head()
# Out:
#              Original titlÊ  Release year                Genrë¨ Duration  \
# 0  The Shawshank Redemption    1995-02-10                 Drama      142
# 1             The Godfather    09 21 1972          Crime, Drama      175
# 2           The Dark Knight   23 -07-2008  Action, Crime, Drama      152
# 3    The Godfather: Part II    1975-09-25          Crime, Drama      220
# 4              Pulp Fiction    1994-10-28          Crime, Drama
#
#   Country Content Rating              Director         Income     Votes  Score
# 0     USA              R        Frank Darabont     $ 28815245  2.278.845   9.3
# 1     USA              R  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2      US          PG-13     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3     USA              R  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0
# 4     USA              R     Quentin Tarantino    $ 222831817  1.780.147  8,9f

# %% [markdown]
# # Renaming columns, and replacing spaces with underscore in the column names.

# %%
# Renaming some columns and reassigning it to the dataframe with the inplace argument.

df.rename(columns = {'Original titlÊ': 'movie title', 'Genrë¨':'genre', 'Content Rating':'rating', ' Votes ':'votes'}, inplace=True)

# %%
# Replacing whitespace in column names with underscore, and converting column names to lowercase.

df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df.head(3)
# Out:
#                 movie_title  release_year                 genre duration  \
# 0  The Shawshank Redemption    1995-02-10                 Drama      142
# 1             The Godfather    09 21 1972          Crime, Drama      175
# 2           The Dark Knight   23 -07-2008  Action, Crime, Drama      152
#
#   country rating              director        income      votes score
# 0     USA      R        Frank Darabont    $ 28815245  2.278.845   9.3
# 1     USA      R  Francis Ford Coppola   $ 246120974  1.572.674   9.2
# 2      US  PG-13     Christopher Nolan  $ 1005455211  2.241.615    9.

# %% [markdown]
# # Cleaning the dataset

# %% [markdown]
# ## Cleaning the 'country' column.
#  ### 1. Accessing the unique countries in the _country_ column
#  ### 2. Replacing countries with multiple variations

# %%
# Access the unique countries in the 'country' coolumn. 

df.country.unique()
# Out:
# array(['USA', 'US', 'New Zealand', 'UK', 'New Zesland', 'Italy', nan,
#        'New Zeland', 'US.', 'Brazil', 'Japan', 'Italy1', 'South Korea',
#        'France', 'Germany', 'India', 'Denmark', 'West Germany', 'Iran'],
#       dtype=object)

# %%
# Replacing countries with multiple variations. Example USA == US, New Zealand == New Zesland etc.

df.country.replace({'US.':'USA', 'US':'USA', 'New Zesland':'New Zealand', 'West Germany':'Germany', 
                    'Italy1':'Italy', 'NaN':'None'}, inplace=True)
df.country.unique()
# Out:
# array(['USA', 'New Zealand', 'UK', 'Italy', nan, 'New Zeland', 'Brazil',
#        'Japan', 'South Korea', 'France', 'Germany', 'India', 'Denmark',
#        'Iran'], dtype=object)

# %% [markdown]
# ## Split the genre column into two by ',' delimiter then extract the first genre.

# %%
# Spliting the genre column to extract only the first genre.

df.genre = df.genre.str.split(',', n=1, expand=True)[0]

# %%
df.head()
# Out:
#                 movie_title  release_year   genre duration country rating  \
# 0  The Shawshank Redemption    1995-02-10   Drama      142     USA      R
# 1             The Godfather    09 21 1972   Crime      175     USA      R
# 2           The Dark Knight   23 -07-2008  Action      152     USA  PG-13
# 3    The Godfather: Part II    1975-09-25   Crime      220     USA      R
# 4              Pulp Fiction    1994-10-28   Crime              USA      R
#
#                director         income      votes score
# 0        Frank Darabont     $ 28815245  2.278.845   9.3
# 1  Francis Ford Coppola    $ 246120974  1.572.674   9.2
# 2     Christopher Nolan   $ 1005455211  2.241.615    9.
# 3  Francis Ford Coppola  $ 4o8,035,783  1.098.714  9,.0
# 4     Quentin Tarantino    $ 222831817  1.780.147  8,9f

# %% [markdown]
# ## Accessing the unique values in the *rating* column, their counts, and sum of null values if any. Then replace the null values and leave data type as is.

# %%
# Accessing the unique values and their counts in the 'rating' column

print("Unique ratings: ", df.rating.unique())
print("\nSum of unique ratings: ")
print(df.rating.value_counts(), '\n')
print("Sum of null values: ", sum(df.rating.isnull()))
# Out:
# Unique ratings:  ['R' 'PG-13' 'Not Rated' 'Approved' nan 'PG' 'Unrated' 'G']
#
# Sum of unique ratings:
# R            45
# PG-13        12
# PG           11
# G             6
# Not Rated     1
# Approved      1
# Unrated       1
# Name: rating, dtype: int64
#
# Sum of null values:  24

# %%
# Replacing the null values with 'Unrated' using the np.NaN argument

df.rating.replace(np.NaN, 'Unrated', inplace=True)
print(df.rating.value_counts())
# Out:
# R            45
# Unrated      25
# PG-13        12
# PG           11
# G             6
# Not Rated     1
# Approved      1
# Name: rating, dtype: int64

# %% [markdown]
# ## Removing special characters, replacing alphabets with string digits then converting *income* column to integer data type.

# %%
# Removing the '$' and ',' in the 'income' column, and converting it to an int datatype.

df.income = df.income.str.lstrip('$ ').str.replace(',', '').str.replace('o', '0').fillna(0).astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_title   100 non-null    object
#  1   release_year  100 non-null    object
#  2   genre         100 non-null    object
#  3   duration      99 non-null     object
#  4   country       100 non-null    object
#  5   rating        101 non-null    object
#  6   director      100 non-null    object
#  7   income        101 non-null    int64
#  8   votes         100 non-null    object
#  9   score         100 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 8.0+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
# Drops the 13th row as all values in that row are NaN

df.drop(13, axis=0, inplace=True)

# %%
df.reset_index()
# Out:
#     index                                        movie_title  \
# 0       0                           The Shawshank Redemption
# 1       1                                      The Godfather
# 2       2                                    The Dark Knight
# 3       3                             The Godfather: Part II
# 4       4                                       Pulp Fiction
# 5       5      The Lord of the Rings: The Return of the King
# 6       6                                   Schindler's List
# 7       7                                       12 Angry Men
# 8       8                                          Inception
# 9       9                                         Fight Club
# 10     10                                       Forrest Gump
# 11     11  The Lord of the Rings: The Fellowship of the Ring
# 12     12                    Il buono, il brutto, il cattivo
# 13     14                                         The Matrix
# 14     15              The Lord of the Rings: The Two Towers
# 15     16     Star Wars: Episode V - The Empire Strikes Back
# 16     17                                         Goodfellas
# 17     18                    One Flew Over the Cuckoo's Nest
# 18     19                                       Interstellar
# 19     20                                              Se7en
# 20     21                           The Silence of the Lambs
# 21     22                                          Star Wars
# 22     23                                Saving Private Ryan
# 23     24                                     The Green Mile
# 24     25                                     Cidade de Deus
# 25     26                      Sen to Chihiro no kamikakushi
# 26     27                                   La vita B9 bella
# 27     28                                       Gisaengchung
# 28     29                              It's a Wonderful Life
# 29     30                               Shichinin no samurai
# 30     31                                          Gladiator
# 31     32                                       The Departed
# 32     33                                       The Prestige
# 33     34                                 Back to the Future
# 34     35                                 American History X
# 35     36                                              LÃ©on
# 36     37                         Terminator 2: Judgment Day
# 37     38                                 The Usual Suspects
# 38     39                                      The Lion King
# 39     40                                              Joker
# 40     41                                       Intouchables
# 41     42                                        The Pianist
# 42     43                                           Whiplash
# 43     44                                             Psycho
# 44     45                                         Casablanca
# 45     46                            C'era una volta il West
# 46     47                                     Hotaru no haka
# 47     48                              Nuovo Cinema Paradiso
# 48     49                                       Modern Times
# 49     50                              The Dark Knight Rises
# 50     51                                   Django Unchained
# 51     52                                            Memento
# 52     53                                            WALLÂ·E
# 53     54                                        The Shining
# 54     55                            Raiders of the Lost Ark
# 55     56                             Avengers: Infinity War
# 56     57                                              Alien
# 57     58                                  Avengers: Endgame
# 58     59                                     Apocalypse Now
# 59     60                                           Oldeuboi
# 60     61  Dr. Strangelove or: How I Learned to Stop Worr...
# 61     62                                        Rear Window
# 62     63                                               Coco
# 63     64                              Das Leben der Anderen
# 64     65                  Spider-Man: Into the Spider-Verse
# 65     66                                           3 Idiots
# 66     67                                      Mononoke-hime
# 67     68                        Once Upon a Time in America
# 68     69                                 The Great Dictator
# 69     70                                       Sunset Blvd.
# 70     71                               Inglourious Basterds
# 71     72                                    American Beauty
# 72     73                                         Braveheart
# 73     74         Star Wars: Episode VI - Return of the Jedi
# 74     75                                     Reservoir Dogs
# 75     76              Eternal Sunshine of the Spotless Mind
# 76     77                                          Toy Story
# 65    Unrated                   Rajkumar Hirani    60262836    332.217     8.1
# 66      PG-13                    Hayao Miyazaki   169785629    331.045     8.0
# 67          R                      Sergio Leone     5472914    302.317     8.0
# 68    Unrated                   Charles Chaplin      969879    197.381     8.0
# 69    Unrated                      Billy Wilder      299645    195.789     8.0
# 70          R                 Quentin Tarantino   321455689  1.229.958     8.0
# 71          R                        Sam Mendes   356296601  1.049.009     8.0
# 72          R                        Mel Gibson   213216216    941.683     7.9
# 73         PG                  Richard Marquand   475347111    928.036     7.9
# 74          R                 Quentin Tarantino     2889963    896.551     7.9
# 75          R                     Michel Gondry    74036715    889.875     7.9
# 76          G                     John Lasseter   404265438    864.461     7.9
# 77          R                      Gus Van Sant   225933435    837.379     7.8
# 78          R                       Guy Ritchie    83557872    766.589     7.8
# 79          R                  Darren Aronofsky     7390108    748.291     7.8
# 80    Unrated                   Stanley Kubrick    26903440    740.301     7.8
# 81          G                       Lee Unkrich  1066969703    739.717     7.8
# 82          R                    Brian De Palma    66023585    721.343     7.8
# 83          R                   Martin Scorsese    28441292    703.264     7.7
# 84          R                Jean-Pierre Jeunet   173924742    690.480     7.7
# 85    Unrated                   Stanley Kubrick    46357676    658.175     7.7
# 86          R                     James Cameron   131384634    639.500     7.7
# 87          G                   Stanley Kubrick    68989547    587.866     7.6
# 88    Unrated                      Orson Welles     1594107    389.322     7.6
# 89    Unrated                        Sam Mendes   384857224    362.897     7.6
# 90          R                      Milos Forman    52066791    361.028     7.6
# 91    Unrated                  Alfred Hitchcock     7796389    352.786     7.5
# 92    Unrated                  Alfred Hitchcock       73446    291.628     7.5
# 93          R                 Thomas Vinterberg    15843274    269.616     7.5
# 94         PG                        David Lean    45710874    261.504     7.5
# 95         PG                   George Roy Hill   156000000    236.285     7.5
# 96          R                 Wolfgang Petersen    11487676    226.427     7.5
# 97    Unrated                      Sergio Leone    15000000    226.039     7.4
# 98      PG-13                    Asghar Farhadi    22926076    214.165     7.4
# 99    Unrated                     Stanley Donen     1864182    213.152     7.4

# %% [markdown]
# ## Convert the *release_year* column to datetime data type.

# %%
df.release_year = pd.to_datetime(df.release_year, errors='coerce', infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_title   100 non-null    object
#  1   release_year  97 non-null     datetime64[ns]
#  2   genre         100 non-null    object
#  3   duration      99 non-null     object
#  4   country       100 non-null    object
#  5   rating        100 non-null    object
#  6   director      100 non-null    object
#  7   income        100 non-null    int64
#  8   votes         100 non-null    object
#  9   score         100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 8.6+ KB

# %% [markdown]
# ## Score and Votes column cleaning.
#
# ### . Replaced unwanted characters and converting the *score* column to float data type.

# %%
df.score.unique()
# Out:
# array(['9.3', '9.2', '9.', '9,.0', '8,9f', '08.9', '8.9', '8..8', '8.8',
#        '8:8', '++8.7', '8.7.', '8,7e-0', '8.7', '8.6', '8,6', '8.5',
#        '8.4', '8.3', '8.2', '8.1', '8.0', '7.9', '7.8', '7.7', '7.6',
#        '7.5', '7.4'], dtype=object)

# %%
df.score = df.score.str.strip('+')

# %%
df.score = df.score.str.rstrip('e-0')

# %%
df.score = df.score.str.rstrip('.')

# %%
df.score = df.score.str.rstrip('f')

# %%
df.score = df.score.str.replace(',', '.')

# %%
df.score = df.score.str.replace(':', '.')

# %%
df.score = df.score.str.replace('..', '.', regex=False)

# %%
df.score.unique()
# Out:
# array(['9.3', '9.2', '9', '9.', '8.9', '08.9', '8.8', '8.7', '8.6', '8.5',
#        '8.4', '8.3', '8.2', '8.1', '8', '7.9', '7.8', '7.7', '7.6', '7.5',
#        '7.4'], dtype=object)

# %%
# Converting 'score' column data type to float.

df.score = df.score.astype(float)

# %%
df.score.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 100 entries, 0 to 100
# Series name: score
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    float64
# dtypes: float64(1)
# memory usage: 1.6 KB

# %%
df.votes.unique()
# Out:
# array(['2.278.845', '1.572.674', '2.241.615', '1.098.714', '1.780.147',
#        '1.604.280', '1.183.248', '668.473', '2.002.816', '1.807.440',
#        '1.755.490', '1.619.920', '672.499', '1.632.315', '1.449.778',
#        '1.132.073', '991.505', '891.071', '1.449.256', '1.402.015',
#        '1.234.134', '1.204.107', '1.203.825', '1.112.336', '685.856',
#        '626.693', '605.648', '470.931', '388.310', '307.958', '1.308.193',
#        '1.159.703', '1.155.723', '1.027.330', '1.014.218', '1.007.598',
#        '974.970', '968.947', '917.248', '855.097', '736.691', '707.942',
#        '690.732', '586.765', '509.953', '295.220', '225.438', '223.050',
#        '211.250', '1.480.582', '1.317.856', '1.098.879', '974.734',
#        '869.480', '865.510', '796.486', '768.874', '754.786', '591.251',
#        '501.082', '441.115', '432.390', '352.455', '349.642', '335.892',
#        '332.217', '331.045', '302.317', '197.381', '195.789', '1.229.958',
#        '1.049.009', '941.683', '928.036', '896.551', '889.875', '864.461',
#        '837.379', '766.589', '748.291', '740.301', '739.717', '721.343',
#        '703.264', '690.480', '658.175', '639.500', '587.866', '389.322',
#        '362.897', '361.028', '352.786', '291.628', '269.616', '261.504',
#        '236.285', '226.427', '226.039', '214.165', '213.152'],
#       dtype=object)

# %%
# Replacing '.' with an empty string, and converting the 'votes' column to integer data type.

df.votes = df.votes.str.replace('.', '', regex=False).astype(np.int64)

# %%
df.votes.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 100 entries, 0 to 100
# Series name: votes
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    int64
# dtypes: int64(1)
# memory usage: 1.6 KB

# %%
df.head()
# Out:
#                 movie_title release_year   genre duration country rating  \
# 0  The Shawshank Redemption   1995-02-10   Drama      142     USA      R
# 1             The Godfather   1972-09-21   Crime      175     USA      R
# 2           The Dark Knight   2008-07-23  Action      152     USA  PG-13
# 3    The Godfather: Part II   1975-09-25   Crime      220     USA      R
# 4              Pulp Fiction   1994-10-28   Crime              USA      R
#
#                director      income    votes  score
# 0        Frank Darabont    28815245  2278845    9.3
# 1  Francis Ford Coppola   246120974  1572674    9.2
# 2     Christopher Nolan  1005455211  2241615    9.0
# 3  Francis Ford Coppola   408035783  1098714    9.0
# 4     Quentin Tarantino   222831817  1780147    8.9

# %% [markdown]
# ## Cleaning the *duration* column.

# %%
df.duration.unique()
# Out:
# array(['142', '175', '152', '220', ' ', '201', 'Nan', '96', '148', 'Inf',
#        '178c', '161', nan, '179', 'Not Applicable', '146', '-', '169',
#        '127', '118', '121', '189', '130', '125', '116', '132', '207',
#        '155', '151', '119', '110', '137', '106', '88', '122', '112',
#        '150', '109', '102', '165', '89', '87', '164', '113', '98', '115',
#        '149', '117', '181', '147', '120', '95', '105', '170', '134',
#        '229', '153', '178', '131', '99', '108', '81', '126', '104', '136',
#        '103', '114', '160', '128', '228', '129', '123'], dtype=object)

# %%
# Replace inf and NaN data type with 0

pd.set_option('use_inf_as_na', True)
df.duration = df.duration.str.strip('c')
df.duration = df.duration.str.replace('Not Applicable', '0')
df.duration = df.duration.str.replace('-', '0')
df.duration = df.duration.str.replace(' ', '0')

# %%
df.duration = pd.to_numeric(df.duration, errors='coerce')
df.duration = df.duration.fillna(0)

# %%
df.duration = df.duration.astype(np.int64)

# %%
df.duration.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 100 entries, 0 to 100
# Series name: duration
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    int64
# dtypes: int64(1)
# memory usage: 1.6 KB

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# # Final Result

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_title   100 non-null    object
#  1   release_year  97 non-null     datetime64[ns]
#  2   genre         100 non-null    object
#  3   duration      100 non-null    int64
#  4   country       100 non-null    object
#  5   rating        100 non-null    object
#  6   director      100 non-null    object
#  7   income        100 non-null    int64
#  8   votes         100 non-null    int64
#  9   score         100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 8.6+ KB
# None

# %%
df
# Out:
#                      movie_title release_year      genre  duration  country  \
# 0       The Shawshank Redemption   1995-02-10      Drama       142      USA
# 1                  The Godfather   1972-09-21      Crime       175      USA
# 2                The Dark Knight   2008-07-23     Action       152      USA
# 3         The Godfather: Part II   1975-09-25      Crime       220      USA
# 4                   Pulp Fiction   1994-10-28      Crime         0      USA
# ..                           ...          ...        ...       ...      ...
# 96                     The Sting   1974-03-21     Comedy       129      USA
# 97                      Das Boot   1982-03-18  Adventure       149  Germany
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western       132    Italy
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama       123     Iran
# 100          Singin' in the Rain   1953-02-05     Comedy       103      USA
#
#       rating              director      income    votes  score
# 0          R        Frank Darabont    28815245  2278845    9.3
# 1          R  Francis Ford Coppola   246120974  1572674    9.2
# 2      PG-13     Christopher Nolan  1005455211  2241615    9.0
# 3          R  Francis Ford Coppola   408035783  1098714    9.0
# 4          R     Quentin Tarantino   222831817  1780147    8.9
# ..       ...                   ...         ...      ...    ...
# 96        PG       George Roy Hill   156000000   236285    7.5
# 97         R     Wolfgang Petersen    11487676   226427    7.5
# 98   Unrated          Sergio Leone    15000000   226039    7.4
# 99     PG-13        Asghar Farhadi    22926076   214165    7.4
# 100  Unrated         Stanley Donen     1864182   213152    7.4
#
# [100 rows x 10 columns]

# %%
df.to_csv('Cleaned_MessyData.csv', encoding='Latin-1', sep=',')
